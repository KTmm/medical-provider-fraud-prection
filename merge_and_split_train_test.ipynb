# %%
import pandas as pd
df_mz = pd.read_csv('../project2/df_provider_mz.csv')
df_mz
# Out:
#       Provider  uniqBeneCount  ClmsperBene  TotalInscClaimAmtReimbursed  \
# 0     PRV51001             24     1.041667                       104640
# 1     PRV51003            117     1.128205                       605670
# 2     PRV51004            138     1.079710                        52170
# 3     PRV51005            495     2.353535                       280910
# 4     PRV51007             58     1.241379                        33710
# ...        ...            ...          ...                          ...
# 5405  PRV57759             24     1.166667                        10640
# 5406  PRV57760              9     2.444444                         4770
# 5407  PRV57761             67     1.223881                        18470
# 5408  PRV57762              1     1.000000                         1900
# 5409  PRV57763             70     1.685714                        43610
#
#       MeanInscClaimAmtReimbursed  MaxInscClaimAmtReimbursed  uniqATPhysnCount  \
# ...

# %%
df_wx = pd.read_csv('../project2/Feature_Xin.csv', index_col=0)
df_wx = df_wx.rename(columns={'Claim_Period': 'ClaimPeriod', 'Race1_percent' : 'RaceOneFrac', 'Racemajor' : 'MajorRace', 'ClaimID': 'ClaimCounts'})
df_wx
# Out:
#       Provider  ClaimCounts  Gender  ClaimPeriod  RaceOneFrac  MajorRace  \
# 0     PRV51001           25   0.360        2.440        0.840          1
# 1     PRV51003          132   0.409        4.674        0.811          1
# 2     PRV51004          149   0.309        2.430        0.805          1
# 3     PRV51005         1165   0.439        2.088        0.767          1
# 4     PRV51007           72   0.472        1.958        0.806          1
# ...        ...          ...     ...          ...          ...        ...
# 5405  PRV57759           28   0.571        3.143        0.786          1
# 5406  PRV57760           22   0.773        1.318        0.818          1
# 5407  PRV57761           82   0.488        2.390        0.854          1
# 5408  PRV57762            1   1.000        1.000        1.000          1
# 5409  PRV57763          118   0.475        2.720        0.831          1
#
#       RenalDiseaseIndicator   Age
# 0                     0.320  79.0
# ...

# %%
df_ys = pd.read_csv('../project2/provider_ys_agg.csv')
df_ys
# Out:
#       Provider PotentialFraud  DeductibleAmtPaid_mean  DeductibleAmtPaid_max  \
# 0     PRV51001             No              213.600000                 1068.0
# 1     PRV51003            Yes              502.166667                 1068.0
# 2     PRV51004             No                2.080537                  100.0
# 3     PRV51005            Yes                3.175966                  200.0
# 4     PRV51007             No               45.333333                 1068.0
# ...        ...            ...                     ...                    ...
# 5405  PRV57759             No                4.642857                   90.0
# 5406  PRV57760             No                0.000000                    0.0
# 5407  PRV57761             No                4.512195                   90.0
# 5408  PRV57762             No                0.000000                    0.0
# 5409  PRV57763             No                3.305085                  100.0
#
# ...

# %%
df_scc = pd.read_csv('../project2/provider_scc_df.csv', index_col=0)
df_scc.drop(columns=['PotentialFraud'], inplace=True)
df_scc = df_scc.rename(columns={'statecount_uniq': 'StateCount_Uniq', 'state_max' : 'MajorState', 'county_uniq' : 'CountyCount_Uniq',
                               'county_max' : 'MajorCounty', 'sum_IPAnnualReimbursementAmt': 'TotalIPAnnualReimbursementAmt', 
                               'mean_IPAnnualReimbursementAmt': 'MeanIPAnnualReimbursementAmt', 'max_IPAnnualReimbursementAmt' : 'MaxIPAnnualReimbursementAmt',
                               'sum_IPAnnualDeductibleAmtdf' : 'TotalIPAnnualDeductibleAmtdf', 'mean_IPAnnualDeductibleAmt' : 'MeanIPAnnualDeductibleAmt' ,
                               'max_IPAnnualDeductibleAmt': 'MaxIPAnnualDeductibleAmt'})
df_scc
# Out:
#       Provider  StateCount_Uniq  MajorState  CountyCount_Uniq  MajorCounty  \
# 0     PRV51001                1           1                 7          660
# 1     PRV51003                3          11                23          851
# 2     PRV51004                9          52                28          770
# 3     PRV51005                4          25                26          660
# 4     PRV51007                2          25                 6          630
# ...        ...              ...         ...               ...          ...
# 5405  PRV57759                1          45                 2          795
# 5406  PRV57760                1          45                 3          770
# 5407  PRV57761                1          10                 2          410
# 5408  PRV57762                1          21                 1          230
# 5409  PRV57763                3          51                 4          360
#
#       TotalIPAnnualReimbursementAmt  MeanIPAnnualReimbursementAmt  \
# ...

# %%
df_yz = pd.read_csv('../project2/provider_agg_df.csv')
df_yz
# Out:
#       Provider  MaxHospitalDays  MedianHospitalDays  MeanHospitalDays  \
# 0     PRV51001             15.0                 0.0          1.200000
# 1     PRV51003             28.0                 0.0          2.893939
# 2     PRV51004              0.0                 0.0          0.000000
# 3     PRV51005              0.0                 0.0          0.000000
# 4     PRV51007              8.0                 0.0          0.263889
# ...        ...              ...                 ...               ...
# 5405  PRV57759              0.0                 0.0          0.000000
# 5406  PRV57760              0.0                 0.0          0.000000
# 5407  PRV57761              0.0                 0.0          0.000000
# 5408  PRV57762              0.0                 0.0          0.000000
# 5409  PRV57763              0.0                 0.0          0.000000
#
#       Chronic_Alzheimer_Frac  Chronic_Heartfailure_Frac  \
# 0                   0.600000                   0.760000
# ...

# %%
merged_agg_df = df_ys.merge(df_wx, on='Provider', how='left')
merged_agg_df
# Out:
#       Provider PotentialFraud  DeductibleAmtPaid_mean  DeductibleAmtPaid_max  \
# 0     PRV51001             No              213.600000                 1068.0
# 1     PRV51003            Yes              502.166667                 1068.0
# 2     PRV51004             No                2.080537                  100.0
# 3     PRV51005            Yes                3.175966                  200.0
# 4     PRV51007             No               45.333333                 1068.0
# ...        ...            ...                     ...                    ...
# 5405  PRV57759             No                4.642857                   90.0
# 5406  PRV57760             No                0.000000                    0.0
# 5407  PRV57761             No                4.512195                   90.0
# 5408  PRV57762             No                0.000000                    0.0
# 5409  PRV57763             No                3.305085                  100.0
#
# ...

# %%
merged_agg_df = merged_agg_df.merge(df_mz, on='Provider', how='left')
merged_agg_df
# Out:
#       Provider PotentialFraud  DeductibleAmtPaid_mean  DeductibleAmtPaid_max  \
# 0     PRV51001             No              213.600000                 1068.0
# 1     PRV51003            Yes              502.166667                 1068.0
# 2     PRV51004             No                2.080537                  100.0
# 3     PRV51005            Yes                3.175966                  200.0
# 4     PRV51007             No               45.333333                 1068.0
# ...        ...            ...                     ...                    ...
# 5405  PRV57759             No                4.642857                   90.0
# 5406  PRV57760             No                0.000000                    0.0
# 5407  PRV57761             No                4.512195                   90.0
# 5408  PRV57762             No                0.000000                    0.0
# 5409  PRV57763             No                3.305085                  100.0
#
# ...

# %%
merged_agg_df = merged_agg_df.merge(df_scc, on='Provider', how='left')
merged_agg_df
# Out:
#       Provider PotentialFraud  DeductibleAmtPaid_mean  DeductibleAmtPaid_max  \
# 0     PRV51001             No              213.600000                 1068.0
# 1     PRV51003            Yes              502.166667                 1068.0
# 2     PRV51004             No                2.080537                  100.0
# 3     PRV51005            Yes                3.175966                  200.0
# 4     PRV51007             No               45.333333                 1068.0
# ...        ...            ...                     ...                    ...
# 5405  PRV57759             No                4.642857                   90.0
# 5406  PRV57760             No                0.000000                    0.0
# 5407  PRV57761             No                4.512195                   90.0
# 5408  PRV57762             No                0.000000                    0.0
# 5409  PRV57763             No                3.305085                  100.0
#
# ...

# %%
merged_agg_df = merged_agg_df.merge(df_yz, on='Provider', how='left')
merged_agg_df
# Out:
#       Provider PotentialFraud  DeductibleAmtPaid_mean  DeductibleAmtPaid_max  \
# 0     PRV51001             No              213.600000                 1068.0
# 1     PRV51003            Yes              502.166667                 1068.0
# 2     PRV51004             No                2.080537                  100.0
# 3     PRV51005            Yes                3.175966                  200.0
# 4     PRV51007             No               45.333333                 1068.0
# ...        ...            ...                     ...                    ...
# 5405  PRV57759             No                4.642857                   90.0
# 5406  PRV57760             No                0.000000                    0.0
# 5407  PRV57761             No                4.512195                   90.0
# 5408  PRV57762             No                0.000000                    0.0
# 5409  PRV57763             No                3.305085                  100.0
#
# ...

# %%
'''export to csv'''
from pathlib import Path
merged_all = Path('../project2/merged_num.csv')
merged_agg_df.to_csv(merged_all, index=False)

# %%
merged_agg_df['PotentialFraud'] = merged_agg_df['PotentialFraud'].apply(lambda x : 1 if x == 'Yes' else 0)

# %%
merged_agg_fraud = merged_agg_df[merged_agg_df['PotentialFraud'] == 1]
merged_agg_fraud
# Out:
#       Provider  PotentialFraud  DeductibleAmtPaid_mean  DeductibleAmtPaid_max  \
# 1     PRV51003               1              502.166667                 1068.0
# 3     PRV51005               1                3.175966                  200.0
# 13    PRV51021               1              122.536965                 1068.0
# 25    PRV51037               1               56.220264                 1068.0
# 37    PRV51052               1               51.000000                 1068.0
# ...        ...             ...                     ...                    ...
# 5307  PRV57642               1              114.836364                 1068.0
# 5324  PRV57667               1             1068.000000                 1068.0
# 5329  PRV57672               1                4.352941                  200.0
# 5351  PRV57697               1              773.323077                 1068.0
# 5360  PRV57709               1              145.842593                 1068.0
#
# ...

# %%
merged_agg_non_fraud = merged_agg_df[merged_agg_df['PotentialFraud'] == 0]
merged_agg_non_fraud
# Out:
#       Provider  PotentialFraud  DeductibleAmtPaid_mean  DeductibleAmtPaid_max  \
# 0     PRV51001               0              213.600000                 1068.0
# 2     PRV51004               0                2.080537                  100.0
# 4     PRV51007               0               45.333333                 1068.0
# 5     PRV51008               0               53.860465                 1068.0
# 6     PRV51011               0               23.586207                 1068.0
# ...        ...             ...                     ...                    ...
# 5405  PRV57759               0                4.642857                   90.0
# 5406  PRV57760               0                0.000000                    0.0
# 5407  PRV57761               0                4.512195                   90.0
# 5408  PRV57762               0                0.000000                    0.0
# 5409  PRV57763               0                3.305085                  100.0
#
# ...

# %%
import numpy as np
from sklearn.model_selection import train_test_split
y = merged_agg_df['PotentialFraud']
y
# Out:
# 0       0
# 1       1
# 2       0
# 3       1
# 4       0
#        ..
# 5405    0
# 5406    0
# 5407    0
# 5408    0
# 5409    0
# Name: PotentialFraud, Length: 5410, dtype: int64

# %%
X = merged_agg_df.drop(columns=['PotentialFraud'])
X
# Out:
#       Provider  DeductibleAmtPaid_mean  DeductibleAmtPaid_max  \
# 0     PRV51001              213.600000                 1068.0
# 1     PRV51003              502.166667                 1068.0
# 2     PRV51004                2.080537                  100.0
# 3     PRV51005                3.175966                  200.0
# 4     PRV51007               45.333333                 1068.0
# ...        ...                     ...                    ...
# 5405  PRV57759                4.642857                   90.0
# 5406  PRV57760                0.000000                    0.0
# 5407  PRV57761                4.512195                   90.0
# 5408  PRV57762                0.000000                    0.0
# 5409  PRV57763                3.305085                  100.0
#
#       NoOfMonths_PartACov_mean  NoOfMonths_PartBCov_mean  \
# 0                    12.000000                 12.000000
# 1                    11.818182                 11.871212
# ...

# %%
X_train_agg, X_test_agg, y_train_agg, y_test_agg = train_test_split(X, y, random_state=10, shuffle=True, test_size=0.2)

# %%
y_train_agg.value_counts()
# Out:
# 0    3925
# 1     403
# Name: PotentialFraud, dtype: int64

# %%
y_test_agg.value_counts()
# Out:
# 0    979
# 1    103
# Name: PotentialFraud, dtype: int64

# %%
train_provider_lst = X_train_agg.Provider

# %%
train_provider_lst
# Out:
# 2370    PRV53960
# 1217    PRV52517
# 3713    PRV55652
# 5053    PRV57328
# 4572    PRV56721
#           ...
# 1180    PRV52471
# 3441    PRV55316
# 1344    PRV52671
# 4623    PRV56782
# 1289    PRV52602
# Name: Provider, Length: 4328, dtype: object

# %%
test_provider_lst = X_test_agg.Provider

# %%
test_provider_lst
# Out:
# 2220    PRV53763
# 2943    PRV54670
# 2840    PRV54542
# 1216    PRV52515
# 2989    PRV54724
#           ...
# 1704    PRV53127
# 557     PRV51699
# 1863    PRV53325
# 5268    PRV57594
# 2036    PRV53544
# Name: Provider, Length: 1082, dtype: object

# %%
y_train_agg
# Out:
# 2370    0
# 1217    0
# 3713    0
# 5053    0
# 4572    0
#        ..
# 1180    0
# 3441    0
# 1344    0
# 4623    0
# 1289    0
# Name: PotentialFraud, Length: 4328, dtype: int64

# %%
'''Export to csv'''
from pathlib import Path
train_provider_list_filepath = Path('../project2/train_provider_list.csv')
train_provider_lst.to_csv(train_provider_list_filepath, index=False)

# %%
test_provider_list_filepath = Path('../project2/test_provider_list.csv')
test_provider_lst.to_csv(test_provider_list_filepath, index=False)

# %%
X_train_agg_filepath = Path('../project2/X_train_aggregated.csv')
X_train_agg.to_csv(X_train_agg_filepath, index=False)

# %%
X_test_agg_filepath = Path('../project2/X_test_aggregated.csv')
X_test_agg.to_csv(X_test_agg_filepath, index=False)

# %%
y_train_agg_filepath = Path('../project2/y_train_agg.csv')
y_train_agg.to_csv(y_train_agg_filepath, index=False)

y_test_agg_filepath = Path('../project2/y_test_agg.csv')
y_test_agg.to_csv(y_test_agg_filepath, index=False)
